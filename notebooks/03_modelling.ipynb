# %%
# sklearn- machine learning library in Python that provides tools for data preprocessing, model training, and evaluation. We can use it to build a simple linear regression model to predict CO2 emissions based on energy usage and number of employees.
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Prepare data for modeling
X = data[["energy_usage", "employees"]]
y = data["co2_emissions"]

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Train a simple linear regression model to predict emissions based on energy usage and number of employees
model = LinearRegression()
model.fit(X_train, y_train)

# %%
# Make predictions on the test set
predictions = model.predict(X_test)
predictions
# results show the predicted emissions for the test set based on the energy usage and number of employees. We can compare these predictions to the actual emissions in y_test to evaluate the model's performance.

# %%
# Evaluate the model using Mean Absolute Error (MAE)

from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, predictions)
mae
# MAE of 4.2 means that on average, our model's predictions are off by 4.2 units of CO2 emissions compared to the actual values in the test set. This gives us an idea of how well our model is performing in terms of accuracy.

# %%
# model coefficients
model.coef_

# %%
# feature names
X.columns

#model is emmissions =(weight x energy usage) + (weight x employees) + error
